# %% [markdown]
# # ECE Board Exam Problem

# %%
#access pandas library
import pandas as pd

# %% [markdown]
# #### 1. Create the following data frames based on the format provided:

# %%
#extract the data from the spreadsheet
df = pd.read_excel('board2.xlsx')
df
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %% [markdown]
# #### a) Filename: Instru = [“Name”, “GEAS”, “Electronics >70”]; where track is constant as instrumentationn and hometown Luzon

# %%
#make a conditional statement to set the conditions
Instru = df[(df['Track'] == "Instrumentation") 
            &(df['Hometown'] == "Luzon") 
            &(df['Electronics'] > 70)]

Instru = Instru[["Name", "GEAS" , "Electronics"]]

Instru
# Out:
#    Name  GEAS  Electronics
# 0    S1    75           89
# 7    S8    64           81
# 29  S30    57           81

# %% [markdown]
# #### b) Filename: Mindy = [ “Name”, “Track”, “Electronics”, “Average >=55”]; where hometown is constant  as Mindanao and gender Female

# %%
# Filter the unnecessary data
Mindy = df[(df['Hometown'] == 'Mindanao') & (df['Gender'] == 'Female')]

# %%
# Compute the average of the subjects
Mindy.loc[:, 'Average'] = Mindy[['Math', 'Electronics', 'GEAS', 'Communication']].mean(axis=1)

# Checks for the students that got an average that is 55 and up
Mindy= Mindy[Mindy['Average'] >= 55]


Mindy = Mindy[['Name', 'Track', 'Electronics', 'Average']]

Mindy
# Out:
# C:\Users\Riley John\AppData\Local\Temp\ipykernel_16840\30560243.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mindy.loc[:, 'Average'] = Mindy[['Math', 'Electronics', 'GEAS', 'Communication']].mean(axis=1)
#    Name             Track  Electronics  Average
# 1    S2     Communication           75    67.25
# 2    S3   Instrumentation           74    72.75
# 14  S15  Microelectronics           41    59.00
# 16  S17  Microelectronics           79    70.50
# 19  S20     Communication           60    66.50

# %%
# Filter the unnecessary data
Mind = df[(df['Hometown'] == 'Mindanao') & (df['Gender'] == 'Female')].copy()

# Compute the average of the subjects
Mindy['Average'] = Mind[['Math', 'Electronics', 'GEAS', 'Communication']].mean(axis=1)

# Checks for the students that got an average that is 55 and up
Mindy = Mindy[Mindy['Average'] >= 55]

# select what columns are to be printed in the Mindy dataframe
Mindy = Mindy[['Name', 'Track', 'Electronics', 'Average']]

# Output the final Mindy DataFrame
Mindy
# Out:
#    Name             Track  Electronics  Average
# 1    S2     Communication           75    67.25
# 2    S3   Instrumentation           74    72.75
# 14  S15  Microelectronics           41    59.00
# 16  S17  Microelectronics           79    70.50
# 19  S20     Communication           60    66.50

# %% [markdown]
# ### 2) Create a visualization that shows how the different features contributes to average grade. Does chosen track in college, gender, or hometown contributes to a higher average score?

# %%
#access maplotlib library and seaborn for the plotting of the graphs
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Get the average of the of the subjects
df['Average'] = df[['Math', 'GEAS', 'Electronics',"Communication"]].mean(axis=1)

#Title of the plot
plt.title('Features that Contributes to Average Grades')

#create a boxplot with the distribution of data
sns.boxplot(x='Track', y='Average', hue='Gender', data=df)

#put labels 
plt.xlabel("Track/Program", fontsize = 12)
plt.ylabel("Average of Grades", fontsize = 12)

#render the boxplot
plt.show()

# %%
#create the figure along with the dimensions
plt.figure(figsize=(16, 8))

plt.style.use("ggplot")

#Title for the plot
plt.title("Average Scores by Hometown", fontsize = 20)

#create a boxplot with the distribution of data
sns.boxplot(x= "Hometown", y= "Average", data=df)

#put label on the x and y axis
plt.ylabel("Average Scores",fontsize = 16 )
plt.xlabel("Hometown by Country",fontsize =16)

#remove borders
sns.despine()

#render the boxplot
plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']
